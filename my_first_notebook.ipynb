# %% [markdown]
# <a href="https://colab.research.google.com/github/JPWHOOO/JustinsRepoPub/blob/main/my_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World! My First Notebook")
# Out:
# Hello World! My First Notebook

# %%
for i in range (-1,100):
  if i !=0:
    print(i, "Number is even")
  else: i%2 ==0
  print(i, "Number is odd")
# Out:
# -1 Number is even
# -1 Number is odd
# 0 Number is odd
# 1 Number is even
# 1 Number is odd
# 2 Number is even
# 2 Number is odd
# 3 Number is even
# 3 Number is odd
# 4 Number is even
# 4 Number is odd
# 5 Number is even
# 5 Number is odd
# 6 Number is even
# 6 Number is odd
# 7 Number is even
# 7 Number is odd
# 8 Number is even
# 8 Number is odd
# 9 Number is even
# 9 Number is odd
# 10 Number is even
# 10 Number is odd
# 11 Number is even
# 11 Number is odd
# 12 Number is even
# 12 Number is odd
# 13 Number is even
# 13 Number is odd
# 14 Number is even
# 14 Number is odd
# 15 Number is even
# 15 Number is odd
# 16 Number is even
# 16 Number is odd
# 17 Number is even
# 17 Number is odd
# 18 Number is even
# 18 Number is odd
# 19 Number is even
# 19 Number is odd
# 20 Number is even
# 20 Number is odd
# 21 Number is even
# 21 Number is odd
# 22 Number is even
# 22 Number is odd
# 23 Number is even
# 23 Number is odd
# 24 Number is even
# 24 Number is odd
# 25 Number is even
# 25 Number is odd
# 26 Number is even
# 26 Number is odd
# 27 Number is even
# 27 Number is odd
# 28 Number is even
# 28 Number is odd
# 29 Number is even
# 29 Number is odd
# 30 Number is even
# 30 Number is odd
# 31 Number is even
# 31 Number is odd
# 32 Number is even
# 32 Number is odd
# 33 Number is even
# 33 Number is odd
# 34 Number is even
# 34 Number is odd
# 35 Number is even
# 35 Number is odd
# 36 Number is even
# 36 Number is odd
# 37 Number is even
# 37 Number is odd
# 38 Number is even
# 38 Number is odd
# 39 Number is even
# 39 Number is odd
# 40 Number is even
# 40 Number is odd
# 41 Number is even
# 41 Number is odd
# 42 Number is even
# 42 Number is odd
# 43 Number is even
# 43 Number is odd
# 44 Number is even
# 44 Number is odd
# 45 Number is even
# 45 Number is odd
# 46 Number is even
# 46 Number is odd
# 47 Number is even
# 47 Number is odd
# 48 Number is even
# 48 Number is odd
# 49 Number is even
# 49 Number is odd
# 50 Number is even
# 50 Number is odd
# 51 Number is even
# 51 Number is odd
# 52 Number is even
# 52 Number is odd
# 53 Number is even
# 53 Number is odd
# 54 Number is even
# 54 Number is odd
# 55 Number is even
# 55 Number is odd
# 56 Number is even
# 56 Number is odd
# 57 Number is even
# 57 Number is odd
# 58 Number is even
# 58 Number is odd
# 59 Number is even
# 59 Number is odd
# 60 Number is even
# 60 Number is odd
# 61 Number is even
# 61 Number is odd
# 62 Number is even
# 62 Number is odd
# 63 Number is even
# 63 Number is odd
# 64 Number is even
# 64 Number is odd
# 65 Number is even
# 65 Number is odd
# 66 Number is even
# 66 Number is odd
# 67 Number is even
# 67 Number is odd
# 68 Number is even
# 68 Number is odd
# 69 Number is even
# 69 Number is odd
# 70 Number is even
# 70 Number is odd
# 71 Number is even
# 71 Number is odd
# 72 Number is even
# 72 Number is odd
# 73 Number is even
# 73 Number is odd
# 74 Number is even
# 74 Number is odd
# 75 Number is even
# 75 Number is odd
# 76 Number is even
# 76 Number is odd
# 77 Number is even
# 77 Number is odd
# 78 Number is even
# 78 Number is odd
# 79 Number is even
# 79 Number is odd
# 80 Number is even
# 80 Number is odd
# 81 Number is even
# 81 Number is odd
# 82 Number is even
# 82 Number is odd
# 83 Number is even
# 83 Number is odd
# 84 Number is even
# 84 Number is odd
# 85 Number is even
# 85 Number is odd
# 86 Number is even
# 86 Number is odd
# 87 Number is even
# 87 Number is odd
# 88 Number is even
# 88 Number is odd
# 89 Number is even
# 89 Number is odd
# 90 Number is even
# 90 Number is odd
# 91 Number is even
# 91 Number is odd
# 92 Number is even
# 92 Number is odd
# 93 Number is even
# 93 Number is odd
# 94 Number is even
# 94 Number is odd
# 95 Number is even
# 95 Number is odd
# 96 Number is even
# 96 Number is odd
# 97 Number is even
# 97 Number is odd
# 98 Number is even
# 98 Number is odd
# 99 Number is even
# 99 Number is odd
